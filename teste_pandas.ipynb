# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.array([[1, 2, 3], [4, 5, 6]]),
                 columns = ['a', 'b', 'c'])

# %%
print(df)
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
df.plot()
# Out:
# <Axes: >
